# %%
import pandas as pd

df = pd.read_csv("../data/passenger_master_with_pfi.csv")

df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Cleanliness  \
# 0                                  4  ...            5
# 1                                  2  ...            1
# 2                                  2  ...            5
# 3                                  5  ...            2
# 4                                  3  ...            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
#               satisfaction  Delay_Score  Service_Quality_Score  \
# 0  neutral or dissatisfied     1.136364               3.857143
# 1  neutral or dissatisfied     0.378788               2.285714
# 2                satisfied     0.000000               3.714286
# 3  neutral or dissatisfied     0.568182               3.000000
# 4                satisfied     0.000000               3.500000
#
#    Service_Dissatisfaction  Travel_Difficulty        PFI  PFI_Category
# 0                22.857143           8.663166  11.330036  Low Friction
# 1                54.285714           4.119548  22.689710  Low Friction
# 2                25.714286          22.435380  14.772790  Low Friction
# 3                40.000000          10.722940  18.371861  Low Friction
# 4                30.000000           3.695477  12.739095  Low Friction
#
# [5 rows x 31 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.cluster import KMeans
#       2 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
persona_features = [
    "Flight Distance",
    "Service_Quality_Score",
    "PFI"
]

# %%
persona_features = [
    "Flight Distance",
    "Service_Quality_Score",
    "PFI"
]

# %%
X = df[persona_features]

X.head()
# Out:
#    Flight Distance  Service_Quality_Score        PFI
# 0              460               3.857143  11.330036
# 1              235               2.285714  22.689710
# 2             1142               3.714286  14.772790
# 3              562               3.000000  18.371861
# 4              214               3.500000  12.739095

# %%
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'
